# %%
from climber.tansformation_utils import apply_homography_to_mediapipe_json

# %%
import json
import pprint

# %%
pose_file_path = 'data/pose.json'

# %%
h = [[1.0729983014292432, -0.23928697532873258, -0.021489534457969306], [-0.0004619049893227412, 1.0820835004833012, -0.10001138385158313], [0.045311155437659976, -0.3852524987029172, 1.0]]

# %%
h
# Out:
# [[1.0729983014292432, -0.23928697532873258, -0.021489534457969306], [-0.0004619049893227412, 1.0820835004833012, -0.10001138385158313], [0.045311155437659976, -0.3852524987029172, 1.0]]

# %%
apply_homography_to_mediapipe_json(pose_file_path, h)
# Out:
# {'type': 'pose', 'timestamp': 1762281159873, 'width': 640, 'height': 480, 'landmarks': [{'x': 0.4844513578397323, 'y': 0.4213644358486891, 'z': -0.4325294494628906, 'visibility': 0.9999807476997375}, {'x': 0.5069096090410198, 'y': 0.3671160735127994, 'z': -0.38958656787872314, 'visibility': 0.9999541640281677}, {'x': 0.522397433906124, 'y': 0.3663883557992138, 'z': -0.38938090205192566, 'visibility': 0.9999558925628662}, {'x': 0.5371495750234394, 'y': 0.36535644338709505, 'z': -0.3898339867591858, 'visibility': 0.9999540448188782}, {'x': 0.455620064931208, 'y': 0.3734258450609381, 'z': -0.39199313521385193, 'visibility': 0.9999573230743408}, {'x': 0.4327682389064257, 'y': 0.37721081511932375, 'z': -0.39178499579429626, 'visibility': 0.9999574422836304}, {'x': 0.41326228861485176, 'y': 0.38112599119505103, 'z': -0.39201146364212036, 'visibility': 0.9999517202377319}, {'x': 0.5500717804002738, 'y': 0.3863272339967807, 'z': -0.1353594958782196, 'visibility': 0.9999518990516663}, {'x': 0
# ...
